# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
test_load = nib.load('/content/patient101_frame01.nii').get_fdata()
test_load.shape
# Out:
# (232, 256, 10)

# %%
test = test_load[:,:,0]
plt.imshow(test)
plt.show()

# %%
test_load = nib.load('/content/DCM04Gate1.nii').get_fdata()
test_load.shape
# Out:
# (232, 256, 10)

# %%
test = test_load[:,:,0]
plt.imshow(test)
plt.show()

# %%
test_load = nib.load('/content/DCM08Gate1.nii').get_fdata()
test = test_load[:,:,0]
plt.imshow(test)
plt.show()

# %%
test_load = nib.load('/content/DCM09Gate1.nii').get_fdata()
test = test_load[:,:,0]
plt.imshow(test)
plt.show()
